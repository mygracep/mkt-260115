# %% [markdown]
# ## 파이썬을 이용한 데이터 분석
# 1) 원하는 데이터 수집 -> 웹사이트에서 크롤링
# 2) 수집해온 데이터 저장 : 엑셀, csv, xml, json
# 3) 저장된 데이터 분석 : SQL
# 4) 데이터 전처리 : 타입(문자, 정수, null)
# 5) 데이터 시각화 : plotly, pandas
# 6) 데이터 예측 : Numpy, pytorch
#
# > 마케팅적 사고관점으로 문제해결 능력 추가 하여 효과적인 인사이트 도출
#
#
# # 크롤링
# -웹사이트에서 내가 원하는 부분을 자동으로 추출해오는 기능
# 1) requests : 정적인 웹사이트(html, css, js)
# 2) selenium : spa 방식으로 구현 (rect.js, vue,ss, angluar,js)
# 3) scrapy : 여러 절차를 거쳐서 방대한 데이터를 가져와야 하는 경우

# %%
import requests # reqeests => 데이터를 수집해오는 크롤러 
import bs4  # bs4 => 찾아온 데이터를 쉽게 이해하고 해석할 수 있는 형태로 바꿔주는 역할 
url = "https://news.daum.net/tech"
headers = {
    "Uuser-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"
}
respons = requests.get(url, headers=headers)
respons.encoding = "utf-8" #  "utf-8" => 한국어를 컴퓨터가 이해할 수 있는 언어로 변환 
soup = bs4.BeautifulSoup(respons. text, "html.parser") # "html.parser" =>html 방식으로 읽어라 

articels = soup.select ("ul.list_newsheadline2 li a.item_newsheadline2")  
# select : 다수의 값 찾아와서 리스트 형태로 반환 / selext_one : 최초의 값 1개만 찾아옴 
# 포함되는 테그 띄어쓰기 그 아래 테그 띄어쓰기 그 안에 클래스 기입 

for article in articels :
    title = article.text.strip()
    link = article["href"]
    print(f"{title} \n {link}")

# %%
#위키피디아에서 '마케팅' 검색 후 결과값 크롤링 

import requests
import bs4

url = "https://ko.wikipedia.org/wiki/%EB%A7%88%EC%BC%80%ED%8C%85"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"
}
rp = requests.get(url, headers=headers)
respons.encoding = "utf-8"
soup = bs4.BeautifulSoup(rp.text, "html.parser")

pg = soup.select("div.mw-content-ltr.mw-parser-output > p") # p가 들어가는 이유?? - 찾아와야할 대상이 p라서 

for p in pg[:2] :
    print(p.get_text().strip())

# %% [markdown]
# 둘다 클래스에서 비롯된 함수
#
# - .text : 속성
# > 텍스트를 여과없이 다 찾아옴 -> 스트립을 써서 보완해야함
#
# -  get_text() : 메서드 함수
#
# ex) <p>안녕<br> <span>반가워요<\span><\p>
# > .text 사용 = p.text
# 안녕
# 반가워요
# >
# > get_text 사용 = get_text(" ", strip=True)

# %%
#문제 실습

import requests
import bs4

url = "https://www.weather.go.kr/w/forecast/overall/short-term.do"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"
}
respons = requests.get(url, headers=headers)
respons.encoding = "utf-8"
soup = bs4.BeautifulSoup(rp.text, "html.parser")

respons = soup.select("p.summery") 
# summary : 여러번 쓰였을수 있기 때문에 동일 단어가 없는지 찾아와야함. 만약 동일한 단어가 있으면 포함하고 있는 상위 테그를 찾아와야함  

for r in respons : 
    print(r.get_text("\n"))

# %%
# 답변 
import requests
import bs4

url = "https://www.weather.go.kr/w/forecast/overall/short-term.do"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"
}
respons = requests.get(url, headers=headers)
respons.encoding = "utf-8"
soup = bs4.BeautifulSoup(rp.text, "html.parser")

tag = soup.select_one("p.summary") 
# summary : 여러번 쓰였을수 있기 때문에 동일 단어가 없는지 찾아와야함. 만약 동일한 단어가 있으면 포함하고 있는 상위 테그를 찾아와야함  

clean_text = tag.get_text("\n")
print(clean_text)
# Out:
# □  (종합) 당분간 전국 강추위, 오늘부터 내일 아침 사이 중부지방과 전라권 중심 눈, 빙판길과 도로 살얼음 주의, 동쪽지역 중심 대기 매우 건조
# ○  (오늘, 23일) 전국 대부분 대체로 맑다가 오후부터 차차 흐려지겠고, 충남권과 전라권, 제주도 대체로 흐림,
#
#                        오후(12~18시)부터 전라권 비 또는 눈,
#
#                        늦은 오후(15~18시)부터 인천.경기서해안과 제주도(비 또는 눈), 밤(18~24시)부터 서울.경기내륙과 강원내륙.산지, 충청권, 경남서부내륙 곳에 따라 눈,
#
#                        오전(12시)까지 충남과 전라권, 낮(12~15시)까지 제주도, 늦은 오후(15~18시)에 그 밖의 수도권 곳에 따라 0.1cm 미만 눈 날림
# ○  (내일, 24일) 전국 대부분 대체로 맑겠으나, 제주도 구름많겠고, 충남권과 전라권 대체로 흐림,
#
#                        이른 새벽(00~03시)까지 경기남부내륙과 강원남부내륙.산지, 새벽(00~06시)까지 충청권과 전라권(서해안 제외), 경상서부내륙, 제주도(비 또는 눈), 아침(06~09시)까지 전라서해안 곳에 따라 눈,
#
#                        이른 새벽(00~03시)에 전라권 곳에 따라 소강상태,
#
#                        새벽(00~06시)에 경북권내륙(서부내륙 제외) 곳에 따라 0.1cm 미만 눈 날림
# ○  (모레, 25일) 전국 대부분 대체로 맑다가 늦은 오후부터 구름많아지겠으나, 전라권과 제주도 가끔 구름많음
# ○  (글피, 26일) 전국 대체로 흐림,
#
#                        오후(12~18시)부터 밤(18~24시) 사이 전남해안과 제주도 곳에 따라 비 또는 눈
#
#
# *  예상 적설(23~24일)
# -  (수도권, 23일) 서해5도: 1~3cm/ 서울.인천.경기(경기남부내륙 24일 이른 새벽까지): 1cm  미만
# -  (강원도) 강원남부내륙.산지: 1~3cm/ (23일) 강원중.북부내륙.산지: 1cm 미만
# -  (충청권) 대전.세종.충남, 충북: 1~3cm
# -  (전라권) 전북서해안, 전남서해안: 2~7cm/ 광주.전남(서해안, 동부남해안 제외), 전북(서해안 제외): 1~5cm/ 전남동부남해안: 1cm 안팎
# -  (경상권) (24~25일) 울릉도.독도: 2~7cm/ 경남서부내륙: 1cm 안팎/ (24일) 경북서부내륙: 1cm 미만
# -  (제주도) 제주도산지: 1~5cm/ 제주도중산간: 1cm 미만
#
#
# *  예상 강수량(23~24일)
# -  (수도권, 23일)  서해5도: 1mm 안팎/ 서울.인천.경기(경기남부내륙 24일 이른 새벽까지): 1mm 미만
# -  (강원도) 강원남부내륙.산지: 1mm 안팎/ (23일) 강원중.북부내륙.산지: 1mm 미만
# -  (충청권) 대전.세종.충남, 충북: 1mm 안팎
# -  (전라권) 전북서해안, 전남서해안: 5mm 안팎/ 광주.전남(서해안, 동부남해안 제외), 전북(서해안 제외): 5mm 미만/ 전남동부남해안: 1mm 안팎
# -  (경상권) (24~25일) 울릉도.독도: 5mm 안팎/ 경남서부내륙: 1mm 안팎/ (24일) 경북서부내륙: 1mm 미만
# -  (제주도) 제주도: 5mm 미만

# %%
# 잡코리아 컨텐츠 마케팅 직무 공고 타이틀 + 링크 10개 수집 

import requests
import bs4

url = "https://www.jobkorea.co.kr/Search/?stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"
}
respons = requests.get(url, headers=headers)
respons.encoding = "utf-8"
soup = bs4.BeautifulSoup(rp.text, "html.parser")


p = soup.select("div.styles_mb_space2__dk46ts4t") 

for px in p :
    title = px.text.strip()
    link = px.select_one("a")["href"]
    print(f"{title}\n {link}")

# %%
# 잡코리아 컨텐츠 마케팅 직무 공고 타이틀 + 링크 10개 수집 

import requests
import bs4

url = "https://www.jobkorea.co.kr/Search/?stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"
}
rp = requests.get(url, headers=headers)
rp.encoding = "utf-8"
soup = bs4.BeautifulSoup(rp.text, "html.parser")


p = soup.select("div.styles_mb_space2__dk46ts4t a") 

number = 1 
for px in p :
    title = px.text.strip()
    link = px["href"]
    print(f"{number} {title}\n {link}")
    number = number + 1
    
    if number > 10 :
        break
# Out:
# 1 [아이디의원/MSO] 네트웍스 글로벌 콘텐츠 마케팅 파트장 채용
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48451944?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=1&sc=551
# 2 [미디어 커머스] SNS 영상 기획/편집 콘텐츠 마케터 모집
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48450064?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=2&sc=551
# 3 SNS 컨텐츠 매니저 (기획/촬영보조/편집) 채용공고
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48448308?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=3&sc=551
# 4 콘텐츠·채널 마케팅 경력직 채용
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48467605?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=1&sc=552
# 5 [로라바운스] 인스타그램 콘텐츠 마케터 채용 (릴스·촬영 중심)
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48427848?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=2&sc=552
# 6 [생활 소독 브랜드 WECHIK] 브랜드 콘텐츠 마케터 채용
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48405786?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=3&sc=552
# 7 [유연근무] SNS 숏폼 PD(뷰티/이너뷰티)
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48394494?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=4&sc=552
# 8 자사 브랜드 SNS 운영 및 컨텐츠 제작 담당자 모집
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48319733?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=5&sc=552
# 9 콘텐츠마케터
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48379478?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=1&sc=630
# 10 [연5000만]영상 콘텐츠마케터 모집
#  https://www.jobkorea.co.kr/Recruit/GI_Read/48410259?Oem_Code=C1&logpath=1&stext=%EC%BD%98%ED%85%90%EC%B8%A0%EB%A7%88%EC%BC%80%ED%84%B0&listno=2&sc=630
