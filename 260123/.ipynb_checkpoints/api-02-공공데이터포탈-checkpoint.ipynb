# %%
import requests

url ="https://apis.data.go.kr/B551011/GoCamping/basedList"
reqest_params = {
    "numOfRows":"10",
    "pageNo":"1",
    "MobileOS":"ETC",
    "MobileApp":"camping",
    "serviceKey":"5b4e36add69e591ff769570c3ea884b7ab691337c5fdf7b7f71fa58c62368a01"
}

# reqests.get 뒤에 넣는 값은 무조건 ditc 형태 
response = requests.get(url, params=reqest_params)
print(response)
# Out:
# <Response [200]>

# %%
# url 값 통째로 찾아오는 방법 
import subprocess

url = "https://apis.data.go.kr/B551011/GoCamping/basedList?numOfRows=10&pageNo=1&MobileOS=ETC&MobileApp=camping&serviceKey=5b4e36add69e591ff769570c3ea884b7ab691337c5fdf7b7f71fa58c62368a01"

result = subprocess.run(["curl", "-k", url], capture_output=True, encoding = "utf-8")
print(result.stdout)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header>
#   <resultCode>0000</resultCode>
#   <resultMsg>OK</resultMsg>
# </header><body><items>
#   <item>
#     <contentId>2837</contentId>
#     <facltNm>진위천유원지 자동차야영장 </facltNm>
#     <lineIntro></lineIntro>
#     <intro></intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2015-1</trsagntNo>
#     <bizrno></bizrno>
#     <facltDivNm>지자체</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>자동차야영장</induty>
#     <lctCl></lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>평택시</sigunguNm>
#     <zipcode>451864</zipcode>
#     <addr1>경기도 평택시 진위면 진위서로 264-15 </addr1>
#     <addr2>진위천 시민유원지 자동차야영장 </addr2>
#     <mapX>127.086486016468</mapX>
#     <mapY>37.09814475902</mapY>
#     <direction></direction>
#     <tel>031-665-6231</tel>
#     <homepage>http://jinweepark.com/main.php</homepage>
#     <resveUrl></resveUrl>
#     <resveCl>전화</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2015-04-16</prmisnDe>
#     <operPdCl></operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,장작판매,온수,물놀이장,놀이터,운동시설</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl></posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2018-09-21</createdtime>
#     <modifiedtime>2026-01-22</modifiedtime>
#   </item>
#   <item>
#     <contentId>7125</contentId>
#     <facltNm>네스트캠핑장</facltNm>
#     <lineIntro>맑은 물이 흐르는 계곡, 바위와 단풍의 경치가 좋은 조용한 가족친화 캠핑장</lineIntro>
#     <intro>가평 화악산 넓은 계곡과 기암절벽이 아름다운 네스트캠핑장</intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2015-12</trsagntNo>
#     <bizrno>496-12-02309</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장</induty>
#     <lctCl>산,숲,계곡</lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>가평군</sigunguNm>
#     <zipcode>12402</zipcode>
#     <addr1>경기도 가평군 북면 화악산로 943-50</addr1>
#     <addr2></addr2>
#     <mapX>127.541317461572</mapX>
#     <mapY>37.9362787859454</mapY>
#     <direction></direction>
#     <tel>010-3889-0443</tel>
#     <homepage>http://m.cafe.naver.com/nestcamping23.cafe?</homepage>
#     <resveUrl>http://www.camfit.co.kr/camp/6409a1065664d7001e06c7de</resveUrl>
#     <resveCl>온라인실시간예약</resveCl>
#     <manageNmpr>2</manageNmpr>
#     <gnrlSiteCo>43</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2015-07-28</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>4</toiletCo>
#     <swrmCo>8</swrmCo>
#     <wtrplCo>6</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,장작판매,온수,산책로,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,산책로</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>30</extshrCo>
#     <frprvtWrppCo>8</frprvtWrppCo>
#     <frprvtSandCo>8</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl></themaEnvrnCl>
#     <eqpmnLendCl>릴선,화로대</eqpmnLendCl>
#     <animalCmgCl>가능(소형견)</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/7125/thumb/thumb_720_5615Yx2qVGQT8dYA4Vsqj4LJ.jpeg</firstImageUrl>
#     <createdtime>2018-12-11</createdtime>
#     <modifiedtime>2026-01-22</modifiedtime>
#   </item>
#   <item>
#     <contentId>100002</contentId>
#     <facltNm>라루체 글램핑 꿈을 노래하다</facltNm>
#     <lineIntro></lineIntro>
#     <intro>사계절 미온수 풀 카라반과 애견가능 카라반 최신 글램핑 시설 / 조식제공 및 하늘자전거 등 풍부한 놀거리 먹거리</intro>
#     <allar>6611</allar>
#     <insrncAt>N</insrncAt>
#     <trsagntNo>2017-6</trsagntNo>
#     <bizrno>854-45-01412</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>김은희</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장,캠프닉</induty>
#     <lctCl>숲,계곡,강</lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>가평군</sigunguNm>
#     <zipcode>12473</zipcode>
#     <addr1>경기 가평군 설악면 유명산길 61-75</addr1>
#     <addr2>1층, 라루체 글램핑 꿈을 노래하다</addr2>
#     <mapX>127.494715155038</mapX>
#     <mapY>37.5978836806172</mapY>
#     <direction>설악IC 로타리에서 좌회전 후 8km 직진 후 어비계곡 쪽으로 좌회전</direction>
#     <tel>010-7760-7204</tel>
#     <homepage></homepage>
#     <resveUrl></resveUrl>
#     <resveCl>전화,온라인예약대기,온라인실시간예약,현장</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>2</glampSiteCo>
#     <caravSiteCo>15</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>8</siteMg1Width>
#     <siteMg2Width>8</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>10</siteMg1Vrticl>
#     <siteMg2Vrticl>10</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>2</siteMg1Co>
#     <siteMg2Co>15</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>1</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>1</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty>침대,TV,에어컨,냉장고,유무선인터넷,난방기구,취사도구,내부화장실,내부샤워실</glampInnerFclty>
#     <caravInnerFclty>침대,TV,에어컨,냉장고,유무선인터넷,난방기구,취사도구,내부화장실,내부샤워실</caravInnerFclty>
#     <prmisnDe>2017-03-09</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>3</toiletCo>
#     <swrmCo>2</swrmCo>
#     <wtrplCo>4</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,산책로,강/물놀이,수영장,청소년체험시설</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>20</extshrCo>
#     <frprvtWrppCo>1</frprvtWrppCo>
#     <frprvtSandCo>1</frprvtSandCo>
#     <fireSensorCo>15</fireSensorCo>
#     <themaEnvrnCl>액티비티,봄꽃여행,여름물놀이,가을단풍명소,겨울눈꽃명소,걷기길</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl>봄,여름,가을,겨울</tourEraCl>
#     <firstImageUrl></firstImageUrl>
#     <createdtime>2021-08-04</createdtime>
#     <modifiedtime>2026-01-22</modifiedtime>
#   </item>
#   <item>
#     <contentId>100423</contentId>
#     <facltNm>신불산 베이스캠프 오토캠핑장</facltNm>
#     <lineIntro>개별 편의시설을 완비한 가족 캠핑</lineIntro>
#     <intro>모든 시설이 사이트별로 구분되어 있어 개별 화장실과 개수대, 샤워실을 편리하게 이용할 수 있습니다. 사계절 온수 수영장이 마련되어 아이와 함께 즐기기 좋으며, 가족 단위 캠핑에 적합한 쾌적한 환경을 제공합니다.</intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo></trsagntNo>
#     <bizrno></bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>자동차야영장</induty>
#     <lctCl>산</lctCl>
#     <doNm>울산광역시</doNm>
#     <sigunguNm>울주군</sigunguNm>
#     <zipcode>44953</zipcode>
#     <addr1>울산광역시 울주군 삼남읍 자수정로 125</addr1>
#     <addr2></addr2>
#     <mapX>129.0976705</mapX>
#     <mapY>35.5381194</mapY>
#     <direction></direction>
#     <tel>010-2507-5542</tel>
#     <homepage>https://www.instagram.com/sinbulsan_basecamp</homepage>
#     <resveUrl>https://camfit.co.kr/camp/670f4db173e56a001d48b7ea</resveUrl>
#     <resveCl>온라인실시간예약</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>58</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>10</siteMg1Width>
#     <siteMg2Width>15</siteMg2Width>
#     <siteMg3Width>7</siteMg3Width>
#     <siteMg1Vrticl>9</siteMg1Vrticl>
#     <siteMg2Vrticl>9</siteMg2Vrticl>
#     <siteMg3Vrticl>7</siteMg3Vrticl>
#     <siteMg1Co>30</siteMg1Co>
#     <siteMg2Co>2</siteMg2Co>
#     <siteMg3Co>26</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>58</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty>TV,에어컨,냉장고,내부화장실,내부샤워실</caravInnerFclty>
#     <prmisnDe>2022-06-09</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>Y</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>30</toiletCo>
#     <swrmCo>30</swrmCo>
#     <wtrplCo>30</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,트렘폴린,물놀이장,운동시설,마트.편의점</sbrsCl>
#     <sbrsEtc>짚라인</sbrsEtc>
#     <posblFcltyCl></posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl>봄꽃여행,가을단풍명소</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/100423/thumb/thumb_720_3667YJMkpwaXxliccgpYcKEF.jpg</firstImageUrl>
#     <createdtime>2022-07-04</createdtime>
#     <modifiedtime>2026-01-22</modifiedtime>
#   </item>
#   <item>
#     <contentId>101102</contentId>
#     <facltNm>글램핑 봄</facltNm>
#     <lineIntro>평택국제대교와 호수뷰가 일품인 럭셔리 글램핑</lineIntro>
#     <intro>벚꽃의 향긋함과 노을의 포근함이 함께하는 글램핑 봄입니다.  글램핑봄을 찾아주신 여러분을 진심으로 환영합니다.  낮에는 벚나무길을 산책하거나 자전거를 타고 저녁에는 평택호의 노을을 바라보며 불멍과 바베큐를 즐기는 등 평화롭고 아늑한 공간에서 여러분만의 시간을 보내보세요.  전 객실에 침대, 주방, 화장실이 구비되어 편안하고 쾌적한 환경에서 휴식할 수 있으며 멋진 뷰와 함께하는 텐트 앞 개별 공간도 마련되어 있습니다.</intro>
#     <allar>4999</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2023-1</trsagntNo>
#     <bizrno>535-87-02790</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>왕현옥</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장,글램핑</induty>
#     <lctCl>호수</lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>평택시</sigunguNm>
#     <zipcode>17979</zipcode>
#     <addr1>경기도 평택시 팽성읍 계양로 561</addr1>
#     <addr2></addr2>
#     <mapX>126.991546702427</mapX>
#     <mapY>36.9413171769658</mapY>
#     <direction></direction>
#     <tel>010-3047-3199</tel>
#     <homepage>https://www.glampingbom.kr/</homepage>
#     <resveUrl>https://www.glampingbom.kr/bbs/board.php?bo_table=reservation</resveUrl>
#     <resveCl>온라인실시간예약</resveCl>
#     <manageNmpr>2</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>14</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2023-09-20</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>14</toiletCo>
#     <swrmCo>14</swrmCo>
#     <wtrplCo>14</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,물놀이장,산책로,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>운동장,낚시,강/물놀이</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>14</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>14</fireSensorCo>
#     <themaEnvrnCl>일출명소,일몰명소,봄꽃여행,여름물놀이,걷기길</themaEnvrnCl>
#     <eqpmnLendCl>화로대,식기</eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl>봄,여름,가을,겨울</tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/101102/thumb/thumb_720_4854MX0GmaBLA4UsbAkbxiD3.jpg</firstImageUrl>
#     <createdtime>2023-10-04</createdtime>
#     <modifiedtime>2026-01-22</modifiedtime>
#   </item>
#   <item>
#     <contentId>101977</contentId>
#     <facltNm>대부도 글램탑 럭셔리 글램핑 &amp; 키즈 수영장 캠핑장</facltNm>
#     <lineIntro>겨울에도 따뜻한 더블 난방시스템은 물론, 보드게임과 스포츠까지 모두 즐길 수 있는 올인원 공간</lineIntro>
#     <intro>겨울에도 따뜻한 더블 난방시스템은 물론, 실내 보드게임과 야외 스포츠까지 모두 즐길 수 있는 올인원 공간입니다. 2025년 11월 오픈한 신축 글램핑장으로, 장비 없이 몸만 오면 되는 간편한 프리미엄 글램핑장입니다.  </intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2025-5</trsagntNo>
#     <bizrno>601-10-06164</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>이현숙</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>글램핑,침대,TV,에어컨,냉장고,유무선인터넷,난방기구,취사도구,내부화장실,내부샤워실</induty>
#     <lctCl>해변,섬,산,숲,도심</lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>안산시</sigunguNm>
#     <zipcode>15640</zipcode>
#     <addr1>경기도 안산시 단원구 연목이2길 3 (대부북동)</addr1>
#     <addr2></addr2>
#     <mapX>126.560518200839</mapX>
#     <mapY>37.2690278257402</mapY>
#     <direction>(대중교통이용시)123번 버스를 타고 [단원자동차운전전문학원]에서 하차 후, 우측으로 돌아 도보로 약 500m 직진합니다. [글램탑 글램핑] 이정표가 있는 곳에서 우측 길로 들어오시면 됩니다. </direction>
#     <tel>0507-1379-7267</tel>
#     <homepage>https://naver.me/Ig4hBWlW</homepage>
#     <resveUrl>https://naver.me/Ig4hBWlW</resveUrl>
#     <resveCl>온라인실시간예약</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>16</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>5</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2025-09-23</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>무선인터넷,장작판매,온수,물놀이장,놀이터,운동장,운동시설,마트.편의점</sbrsCl>
#     <sbrsEtc>개별바비큐 / 자연학습 / 개별 화장실 / 개별샤워실</sbrsEtc>
#     <posblFcltyCl>운동장,수영장,어린이놀이시설</posblFcltyCl>
#     <posblFcltyEtc>동춘서커스(차량 5분), 오션시티 종합어시장(차량 8분), 유리섬박물관(차량 10분), 종이미술관(차량 10분)</posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl>여름물놀이</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl>봄,여름,가을,겨울</tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/101977/thumb/thumb_720_8056HQzxpDJrI8jh8yY8PxIt.jpg</firstImageUrl>
#     <createdtime>2025-10-02</createdtime>
#     <modifiedtime>2026-01-22</modifiedtime>
#   </item>
#   <item>
#     <contentId>101789</contentId>
#     <facltNm>구이PICK</facltNm>
#     <lineIntro>오산 당일캠핑 바베큐장</lineIntro>
#     <intro></intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2025-1</trsagntNo>
#     <bizrno></bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>손왕국</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장,캠프닉</induty>
#     <lctCl>도심</lctCl>
#     <doNm>경기도</doNm>
#     <sigunguNm>오산시</sigunguNm>
#     <zipcode>18102</zipcode>
#     <addr1>경기도 오산시 서랑로 208-13 (지곶동)</addr1>
#     <addr2>서랑로 208-11</addr2>
#     <mapX>127.021614539629</mapX>
#     <mapY>37.1721587091675</mapY>
#     <direction></direction>
#     <tel></tel>
#     <homepage>https://blog.naver.com/92pick</homepage>
#     <resveUrl></resveUrl>
#     <resveCl>전화,온라인실시간예약</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>12</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2025-04-09</prmisnDe>
#     <operPdCl></operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>0</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,트렘폴린,물놀이장,놀이터,마트.편의점</sbrsCl>
#     <sbrsEtc>샤워장, 간이 개수대, 모래놀이터, 불멍존</sbrsEtc>
#     <posblFcltyCl>어린이놀이시설</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>0</frprvtWrppCo>
#     <frprvtSandCo>0</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl>일몰명소,여름물놀이</themaEnvrnCl>
#     <eqpmnLendCl>텐트,난방기구,식기</eqpmnLendCl>
#     <animalCmgCl>가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/101789/thumb/thumb_720_2391AL6Pr5rjGijDUWeYphxF.jpg</firstImageUrl>
#     <createdtime>2025-05-02</createdtime>
#     <modifiedtime>2026-01-21</modifiedtime>
#   </item>
#   <item>
#     <contentId>1356</contentId>
#     <facltNm>비토애 럭셔리 글램핑 산청점</facltNm>
#     <lineIntro>둔철산과 대성산 사이 숲속 골짜기에 자리한 마운틴 뷰 프라이빗 글램핑</lineIntro>
#     <intro>둔철산과 대성산 사이 골짜기에 위치해 울창한 숲이 바로 앞에 펼쳐지는 글램핑 공간입니다. 전 객실에서 마운틴 뷰를 감상할 수 있으며, 객실에서는 아침 일출도 즐길 수 있습니다. 자연에 둘러싸인 조용한 환경에서 프라이빗한 휴식을 원하는 이용객에게 적합한 곳입니다.</intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2015-000004</trsagntNo>
#     <bizrno>146-26-00719</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>정영문</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>글램핑</induty>
#     <lctCl>산,숲</lctCl>
#     <doNm>경상남도</doNm>
#     <sigunguNm>산청군</sigunguNm>
#     <zipcode>52261</zipcode>
#     <addr1>경상남도 산청군 신안면 둔철산로 575-26</addr1>
#     <addr2></addr2>
#     <mapX>127.9649409</mapX>
#     <mapY>35.3818781</mapY>
#     <direction>전남 여수시 돌산읍 안굴전길 59-13</direction>
#     <tel>0507-1426-4677</tel>
#     <homepage>http://bitolove3.co.kr/html/index.html</homepage>
#     <resveUrl>http://bitolove-yeosu.co.kr/html/index.html</resveUrl>
#     <resveCl>전화,온라인실시간예약</resveCl>
#     <manageNmpr>4</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>15</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty>침대,TV,에어컨,냉장고,유무선인터넷,난방기구,취사도구,내부화장실,내부샤워실</glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2015-11-02</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>1</toiletCo>
#     <swrmCo>0</swrmCo>
#     <wtrplCo>0</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,물놀이장,놀이터,산책로,운동시설,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl>계곡 물놀이,산책로</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>0</extshrCo>
#     <frprvtWrppCo>15</frprvtWrppCo>
#     <frprvtSandCo>15</frprvtSandCo>
#     <fireSensorCo>15</fireSensorCo>
#     <themaEnvrnCl>일출명소,액티비티,봄꽃여행,여름물놀이</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>가능</animalCmgCl>
#     <tourEraCl>봄,여름,가을,겨울</tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/1356/thumb/thumb_720_5124HWEz0FjN6NgECVN1mnvc.jpg</firstImageUrl>
#     <createdtime>2018-09-21</createdtime>
#     <modifiedtime>2026-01-20</modifiedtime>
#   </item>
#   <item>
#     <contentId>101666</contentId>
#     <facltNm>비토애럭셔리글램핑</facltNm>
#     <lineIntro>여수 밤바다가 보이는 곳		</lineIntro>
#     <intro>호수처럼 잔잔한 여수 바다와 주변 산 풍경이 어우러진 오션뷰 글램핑 공간입니다. 객실 앞에 펼쳐지는 탁 트인 바다 전경과 밤이 되면 더욱 낭만적인 여수 밤바다를 감상할 수 있습니다. 연인, 가족, 친구와 함께 여수의 바다 풍경을 여유롭게 즐기며 특별한 시간을 보내기에 적합한 곳입니다.</intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2024-3</trsagntNo>
#     <bizrno>284-35-01439</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv>이경숙 외 1명</mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>글램핑</induty>
#     <lctCl>해변,섬</lctCl>
#     <doNm>전라남도</doNm>
#     <sigunguNm>여수시</sigunguNm>
#     <zipcode>59771</zipcode>
#     <addr1>전라남도 여수시 돌산읍 안굴전길 59-13</addr1>
#     <addr2></addr2>
#     <mapX>127.773253914915</mapX>
#     <mapY>34.6953663970225</mapY>
#     <direction></direction>
#     <tel>010-8279-6125</tel>
#     <homepage>http://bitolove-yeosu.co.kr/html/index.html		</homepage>
#     <resveUrl>http://bitolove-yeosu.co.kr/html/index.html			</resveUrl>
#     <resveCl>전화,온라인실시간예약</resveCl>
#     <manageNmpr>0</manageNmpr>
#     <gnrlSiteCo>0</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>14</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>0</siteMg1Co>
#     <siteMg2Co>0</siteMg2Co>
#     <siteMg3Co>0</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>0</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty>침대,TV,에어컨,냉장고,유무선인터넷,난방기구,취사도구,내부화장실,내부샤워실</glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2024-11-28</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>N</trlerAcmpnyAt>
#     <caravAcmpnyAt>N</caravAcmpnyAt>
#     <toiletCo>1</toiletCo>
#     <swrmCo>1</swrmCo>
#     <wtrplCo>1</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,무선인터넷,장작판매,온수,물놀이장,마트.편의점</sbrsCl>
#     <sbrsEtc></sbrsEtc>
#     <posblFcltyCl></posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>1</extshrCo>
#     <frprvtWrppCo>1</frprvtWrppCo>
#     <frprvtSandCo>1</frprvtSandCo>
#     <fireSensorCo>1</fireSensorCo>
#     <themaEnvrnCl>일몰명소,액티비티,봄꽃여행,여름물놀이,걷기길</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl>봄,여름,가을,겨울</tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/101666/thumb/thumb_720_1834njvJPG15NpZ9l0ibKtL9.jpg</firstImageUrl>
#     <createdtime>2024-12-03</createdtime>
#     <modifiedtime>2026-01-20</modifiedtime>
#   </item>
#   <item>
#     <contentId>100258</contentId>
#     <facltNm>배방관광농원</facltNm>
#     <lineIntro>천안아산 근교 힐링여행 마운틴뷰 맛집 배방관광농원캠핑</lineIntro>
#     <intro>멋진 전망과 부대시설을 갖춘 캠핑장  배방관광농원은 충남 아산시 배방읍에 자리 잡고 있다. 배방산 중턱 숲속에 위치한 덕분에 싱그러운 기운이 감돈다. 설화산과 망경산을 조망할 수 있다는 장점도 지녔다. 캠핑장에는 파쇄석으로 이루어진 일반캠핑 사이트 26면이 마련되어 있다. 가로 7m 세로 7m 등 다양한 크기로 구분된다. 캠핑장 내에 있는 대형 카페 비비글로우도 눈에 띈다. 모던한 외관과 세련된 인테리어로 꾸며졌다. 각종 음료와 당일 만든 디저트를 맛볼 수 있다. 캠핑장 이용객에게 쿠폰을 증정한다. 주변에 외암민속마을 등 관광자원이 풍부하다.</intro>
#     <allar>0</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2022-1</trsagntNo>
#     <bizrno>338-88-01159</bizrno>
#     <facltDivNm>민간</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
#     <mgcDiv></mgcDiv>
#     <manageSttus>운영</manageSttus>
#     <hvofBgnde></hvofBgnde>
#     <hvofEnddle></hvofEnddle>
#     <featureNm></featureNm>
#     <induty>일반야영장</induty>
#     <lctCl>산,숲</lctCl>
#     <doNm>충청남도</doNm>
#     <sigunguNm>아산시</sigunguNm>
#     <zipcode>31581</zipcode>
#     <addr1>충청남도 아산시 배방읍 솔치로 17-31</addr1>
#     <addr2></addr2>
#     <mapX>127.0520643</mapX>
#     <mapY>36.7460591</mapY>
#     <direction></direction>
#     <tel>041-545-1731</tel>
#     <homepage>https://www.instagram.com/baebang_camping</homepage>
#     <resveUrl>https://booking.naver.com/booking/3/bizes/672857</resveUrl>
#     <resveCl>온라인실시간예약</resveCl>
#     <manageNmpr>1</manageNmpr>
#     <gnrlSiteCo>25</gnrlSiteCo>
#     <autoSiteCo>0</autoSiteCo>
#     <glampSiteCo>0</glampSiteCo>
#     <caravSiteCo>0</caravSiteCo>
#     <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
#     <sitedStnc>0</sitedStnc>
#     <siteMg1Width>0</siteMg1Width>
#     <siteMg2Width>0</siteMg2Width>
#     <siteMg3Width>0</siteMg3Width>
#     <siteMg1Vrticl>0</siteMg1Vrticl>
#     <siteMg2Vrticl>0</siteMg2Vrticl>
#     <siteMg3Vrticl>0</siteMg3Vrticl>
#     <siteMg1Co>8</siteMg1Co>
#     <siteMg2Co>5</siteMg2Co>
#     <siteMg3Co>5</siteMg3Co>
#     <siteBottomCl1>0</siteBottomCl1>
#     <siteBottomCl2>25</siteBottomCl2>
#     <siteBottomCl3>0</siteBottomCl3>
#     <siteBottomCl4>0</siteBottomCl4>
#     <siteBottomCl5>0</siteBottomCl5>
#     <tooltip></tooltip>
#     <glampInnerFclty></glampInnerFclty>
#     <caravInnerFclty></caravInnerFclty>
#     <prmisnDe>2022-01-21</prmisnDe>
#     <operPdCl>봄,여름,가을,겨울</operPdCl>
#     <operDeCl>평일+주말</operDeCl>
#     <trlerAcmpnyAt>Y</trlerAcmpnyAt>
#     <caravAcmpnyAt>Y</caravAcmpnyAt>
#     <toiletCo>4</toiletCo>
#     <swrmCo>2</swrmCo>
#     <wtrplCo>2</wtrplCo>
#     <brazierCl>개별</brazierCl>
#     <sbrsCl>전기,장작판매,온수,물놀이장,놀이터,운동시설</sbrsCl>
#     <sbrsEtc>카페</sbrsEtc>
#     <posblFcltyCl>산책로,운동장,강/물놀이,어린이놀이시설</posblFcltyCl>
#     <posblFcltyEtc></posblFcltyEtc>
#     <clturEventAt>N</clturEventAt>
#     <clturEvent></clturEvent>
#     <exprnProgrmAt>N</exprnProgrmAt>
#     <exprnProgrm></exprnProgrm>
#     <extshrCo>12</extshrCo>
#     <frprvtWrppCo>2</frprvtWrppCo>
#     <frprvtSandCo>2</frprvtSandCo>
#     <fireSensorCo>0</fireSensorCo>
#     <themaEnvrnCl>봄꽃여행,여름물놀이</themaEnvrnCl>
#     <eqpmnLendCl></eqpmnLendCl>
#     <animalCmgCl>불가능</animalCmgCl>
#     <tourEraCl></tourEraCl>
#     <firstImageUrl>https://gocamping.or.kr/upload/camp/100258/thumb/thumb_720_0570pmwbOa5rrSwdaumyN1xt.jpg</firstImageUrl>
#     <createdtime>2022-02-07</createdtime>
#     <modifiedtime>2026-01-19</modifiedtime>
#   </item>
# </items>  <numOfRows>10</numOfRows>
#   <pageNo>1</pageNo>
#   <totalCount>2996</totalCount>
# </body></response>
